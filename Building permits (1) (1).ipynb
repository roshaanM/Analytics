# %%
#Import the relevant Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#Load the neccessary csv

raw_data = pd.read_csv('Approved_building_permits.csv')
raw_data.head()
# Out:
#   permitnumber worktype           permittypedescr             description  \
# 0     A1000569   INTEXT  Amendment to a Long Form  Interior/Exterior Work
# 1      A100071      COB  Amendment to a Long Form          City of Boston
# 2     A1001012    OTHER  Amendment to a Long Form                   Other
# 3     A1001201   INTEXT  Amendment to a Long Form  Interior/Exterior Work
# 4      A100137   EXTREN  Amendment to a Long Form  Renovations - Exterior
#
#                                             comments          applicant  \
# 0  This work is to Amend Permit ALT347244. Elimin...    Patrick Sharkey
# 1  Change connector link layout from attached enc...  Renee Santeusanio
# 2  Amend Alt943748 to erect a roof deck as per pl...   Jusimar Oliveria
# 3  Build steel balcony over garden level with sta...      Andreas Hwang
# 4  Landscaping/stonework - amending permit #2801/...                NaN
#
#    declared_valuation  total_fees          issued_date      expiration_date  \
# ...

# %%
#Explore the dataset 
raw_data.shape
# Out:
# (566415, 22)

# %%
#create list of column names
column_names = list(raw_data.columns.values)
#read column names from the list
for column_names in raw_data.columns:
    print(column_names)
# Out:
# permitnumber
# worktype
# permittypedescr
# description
# comments
# applicant
# declared_valuation
# total_fees
# issued_date
# expiration_date
# status
# owner
# occupancytype
# sq_feet
# address
# city
# state
# zip
# property_id
# parcel_id
# lat
# long

# %%
df_permits = raw_data[['zip','address', 'city', 'occupancytype',
                       'description','worktype','issued_date','expiration_date','comments' ]] 
df_permits
# Out:
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# 566410  02108              3   Center PZ         Boston         Mixed
# 566411  02108              3   Center PZ         Boston         Mixed
# 566412  02134     1188   Commonwealth Av        Allston          Comm
# 566413  02130         46    Burroughs ST  Jamaica Plain        1-2FAM
# 566414  02124             17    Alpha RD     Dorchester        1-2FAM
#
#                    description worktype          issued_date  \
# 0       Interior/Exterior Work   INTEXT  2021-01-28 11:29:26
# ...

# %%
df_permits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566415 entries, 0 to 566414
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   zip              566246 non-null  object
#  1   address          566334 non-null  object
#  2   city             566359 non-null  object
#  3   occupancytype    566415 non-null  object
#  4   description      561967 non-null  object
#  5   worktype         566415 non-null  object
#  6   issued_date      566415 non-null  object
#  7   expiration_date  566415 non-null  object
#  8   comments         566225 non-null  object
# dtypes: object(9)
# memory usage: 38.9+ MB

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Jamaica Plain/', 'Roslindale',
#        'BOSTON', 'Mission Hill', 'Mattapan', 'Chestnut Hill', 'Roxbury/',
#        'NorthEnd/', 'DORCHESTER', 'South Boston/', 'Mission Hill/',
#        'Boston/West End', 'West End', 'NorthEnd', 'Dorchester/', 'Fenway',
#        'Boston/Roxbury', 'ROXBURY', 'South End', 'BOSTON/',
#        'Charlestown/', 'Back Bay/Boston', ' ', 'Boston/',
#        'Boston/Downtown', "Boston's Historic North End",
#        'Dorchester Center/', 'Financial District', 'Dorchester Center',
#        'Downtown/Financial District', 'Dorchester (Lower Mills)/',
#        'BRIGHTON', 'ALLSTON', 'Dorchester//', 'Fenway/',
#        'Boston/Beacon Hill', 'BOSTON/CHINATOWN', 'Boston/Chinatown',
#        'Chinatown', 'SOUTH BOSTON', 'Hyde Park/', 'South End/',
# ...

# %% [markdown]
# We find significantly inconsistent data in the dataset which needs cleaning.

# %%
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\1173569055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['Jamaica Plain/', 'Jamaica Plain/Boston','jamaica Plain','JAMAICA PLAIN',
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'Roxbury/',
#        'NorthEnd/', 'DORCHESTER', 'South Boston/', 'Mission Hill/',
#        'Boston/West End', 'West End', 'NorthEnd', 'Dorchester/', 'Fenway',
#        'Boston/Roxbury', 'ROXBURY', 'South End', 'BOSTON/',
#        'Charlestown/', 'Back Bay/Boston', ' ', 'Boston/',
#        'Boston/Downtown', "Boston's Historic North End",
#        'Dorchester Center/', 'Financial District', 'Dorchester Center',
#        'Downtown/Financial District', 'Dorchester (Lower Mills)/',
#        'BRIGHTON', 'ALLSTON', 'Dorchester//', 'Fenway/',
#        'Boston/Beacon Hill', 'BOSTON/CHINATOWN', 'Boston/Chinatown',
#        'Chinatown', 'SOUTH BOSTON', 'Hyde Park/', 'South End/',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['Charlestown+-+-+-+-+-+', 'Charlestown+','Boston/Charlestown',
'Charlestown\\=-0=]\\[=-','Charleswtown','CHARLESTOWN', 'Charlestown/Boston','Charlestown/' ], 'Charlestown')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\1288620230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['Charlestown+-+-+-+-+-+', 'Charlestown+','Boston/Charlestown',
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'Roxbury/',
#        'NorthEnd/', 'DORCHESTER', 'South Boston/', 'Mission Hill/',
#        'Boston/West End', 'West End', 'NorthEnd', 'Dorchester/', 'Fenway',
#        'Boston/Roxbury', 'ROXBURY', 'South End', 'BOSTON/',
#        'Back Bay/Boston', ' ', 'Boston/', 'Boston/Downtown',
#        "Boston's Historic North End", 'Dorchester Center/',
#        'Financial District', 'Dorchester Center',
#        'Downtown/Financial District', 'Dorchester (Lower Mills)/',
#        'BRIGHTON', 'ALLSTON', 'Dorchester//', 'Fenway/',
#        'Boston/Beacon Hill', 'BOSTON/CHINATOWN', 'Boston/Chinatown',
#        'Chinatown', 'SOUTH BOSTON', 'Hyde Park/', 'South End/',
#        'BRIGHTON/', 'BOSTON/Waterfront', 'HYDE PARK', nan, 'East Boston/',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['West Roxbry', 'West Roxbury/Chestnut Hill','West Roxbury/',
'WEST ROXBURY' ], 'West Roxbury')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\3641482772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['West Roxbry', 'West Roxbury/Chestnut Hill','West Roxbury/',
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'Roxbury/',
#        'NorthEnd/', 'DORCHESTER', 'South Boston/', 'Mission Hill/',
#        'Boston/West End', 'West End', 'NorthEnd', 'Dorchester/', 'Fenway',
#        'Boston/Roxbury', 'ROXBURY', 'South End', 'BOSTON/',
#        'Back Bay/Boston', ' ', 'Boston/', 'Boston/Downtown',
#        "Boston's Historic North End", 'Dorchester Center/',
#        'Financial District', 'Dorchester Center',
#        'Downtown/Financial District', 'Dorchester (Lower Mills)/',
#        'BRIGHTON', 'ALLSTON', 'Dorchester//', 'Fenway/',
#        'Boston/Beacon Hill', 'BOSTON/CHINATOWN', 'Boston/Chinatown',
#        'Chinatown', 'SOUTH BOSTON', 'Hyde Park/', 'South End/',
#        'BRIGHTON/', 'BOSTON/Waterfront', 'HYDE PARK', nan, 'East Boston/',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['Roxbury/','Boston/Roxbury', 'ROXBURY',
    'ROXBURY CROSSIN','ROXBURY CROSSING','Roxbury/Boston','roxbury'], 'Roxbury')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\1679991697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['Roxbury/','Boston/Roxbury', 'ROXBURY',
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'NorthEnd/',
#        'DORCHESTER', 'South Boston/', 'Mission Hill/', 'Boston/West End',
#        'West End', 'NorthEnd', 'Dorchester/', 'Fenway', 'South End',
#        'BOSTON/', 'Back Bay/Boston', ' ', 'Boston/', 'Boston/Downtown',
#        "Boston's Historic North End", 'Dorchester Center/',
#        'Financial District', 'Dorchester Center',
#        'Downtown/Financial District', 'Dorchester (Lower Mills)/',
#        'BRIGHTON', 'ALLSTON', 'Dorchester//', 'Fenway/',
#        'Boston/Beacon Hill', 'BOSTON/CHINATOWN', 'Boston/Chinatown',
#        'Chinatown', 'SOUTH BOSTON', 'Hyde Park/', 'South End/',
#        'BRIGHTON/', 'BOSTON/Waterfront', 'HYDE PARK', nan, 'East Boston/',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['Brighton / Allston','BRIGHTON','Brighton#','Brigjton','Brighton//'], 'Brighton')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\856004954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['Brighton / Allston','BRIGHTON','Brighton#','Brigjton','Brighton//'], 'Brighton')
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'NorthEnd/',
#        'DORCHESTER', 'South Boston/', 'Mission Hill/', 'Boston/West End',
#        'West End', 'NorthEnd', 'Dorchester/', 'Fenway', 'South End',
#        'BOSTON/', 'Back Bay/Boston', ' ', 'Boston/', 'Boston/Downtown',
#        "Boston's Historic North End", 'Dorchester Center/',
#        'Financial District', 'Dorchester Center',
#        'Downtown/Financial District', 'Dorchester (Lower Mills)/',
#        'ALLSTON', 'Dorchester//', 'Fenway/', 'Boston/Beacon Hill',
#        'BOSTON/CHINATOWN', 'Boston/Chinatown', 'Chinatown',
#        'SOUTH BOSTON', 'Hyde Park/', 'South End/', 'BRIGHTON/',
#        'BOSTON/Waterfront', 'HYDE PARK', nan, 'East Boston/', 'MATTAPAN',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['East Boston/',
                    'East  Boston','EAST BOSTON','E BOSTON','East BOSTON','East Boston/Boston/'], 'East Boston')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\2711962062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['East Boston/',
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'NorthEnd/',
#        'Mission Hill/', 'Boston/West End', 'West End', 'NorthEnd',
#        'Dorchester/', 'Fenway', 'South End', 'BOSTON/', 'Back Bay/Boston',
#        ' ', 'Boston/', 'Boston/Downtown', "Boston's Historic North End",
#        'Financial District', 'Downtown/Financial District', 'ALLSTON',
#        'Fenway/', 'Boston/Beacon Hill', 'BOSTON/CHINATOWN',
#        'Boston/Chinatown', 'Chinatown', 'Hyde Park/', 'South End/',
#        'BRIGHTON/', 'BOSTON/Waterfront', 'HYDE PARK', nan, 'MATTAPAN',
#        'West End/', 'Theater District', 'Mattapan/', 'Brighton/', '/',
#        'Allston/Boston', 'ROSLINDALE', 'Boston/Back Bay', 'Back Bay/',
#        'FENWAY', 'Brighton/Allston', 'BOSTON/Boston', 'Boston/South End',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['Dorchester (Savin Hill)','Dorchester Center//','Dorchester (Lower Mills)',
                     'Dorchester(Lower Mills)', 'Dorchester (Savin Hill)/', 'Dorchester (Savin Hill)/','DORCHESTER/','dorchester',
                      'Dorchester//','Dorchester (Lower Mills)/','Dorchester Center','Dorchester Center/', 'DORCHESTER'
                    ], 'Dorchester')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\1586952826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['Dorchester (Savin Hill)','Dorchester Center//','Dorchester (Lower Mills)',
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'NorthEnd/',
#        'South Boston/', 'Mission Hill/', 'Boston/West End', 'West End',
#        'NorthEnd', 'Dorchester/', 'Fenway', 'South End', 'BOSTON/',
#        'Back Bay/Boston', ' ', 'Boston/', 'Boston/Downtown',
#        "Boston's Historic North End", 'Financial District',
#        'Downtown/Financial District', 'ALLSTON', 'Fenway/',
#        'Boston/Beacon Hill', 'BOSTON/CHINATOWN', 'Boston/Chinatown',
#        'Chinatown', 'SOUTH BOSTON', 'Hyde Park/', 'South End/',
#        'BRIGHTON/', 'BOSTON/Waterfront', 'HYDE PARK', nan, 'MATTAPAN',
#        'West End/', 'Theater District', 'Mattapan/', 'Brighton/', '/',
#        'Allston/Boston', 'ROSLINDALE', 'Boston/Back Bay', 'Back Bay/',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['south boston','South BostonSG', 'Boston/South',
                'South Boston/South Boston','SOUTH BOSTON','South Boston/'], 'South Boston')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\4175823925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['south boston','South BostonSG', 'Boston/South',
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'NorthEnd/',
#        'Mission Hill/', 'Boston/West End', 'West End', 'NorthEnd',
#        'Dorchester/', 'Fenway', 'South End', 'BOSTON/', 'Back Bay/Boston',
#        ' ', 'Boston/', 'Boston/Downtown', "Boston's Historic North End",
#        'Financial District', 'Downtown/Financial District', 'ALLSTON',
#        'Fenway/', 'Boston/Beacon Hill', 'BOSTON/CHINATOWN',
#        'Boston/Chinatown', 'Chinatown', 'Hyde Park/', 'South End/',
#        'BRIGHTON/', 'BOSTON/Waterfront', 'HYDE PARK', nan, 'MATTAPAN',
#        'West End/', 'Theater District', 'Mattapan/', 'Brighton/', '/',
#        'Allston/Boston', 'ROSLINDALE', 'Boston/Back Bay', 'Back Bay/',
#        'FENWAY', 'Brighton/Allston', 'BOSTON/Boston', 'Boston/South End',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['South End','South End/','Boston/South End','BOSTON/SOUTH END', 'South End//' ], 'South End')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\2066379202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['South End','South End/','Boston/South End','BOSTON/SOUTH END', 'South End//' ], 'South End')
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'NorthEnd/',
#        'Mission Hill/', 'Boston/West End', 'West End', 'NorthEnd',
#        'Dorchester/', 'Fenway', 'South End', 'BOSTON/', 'Back Bay/Boston',
#        ' ', 'Boston/', 'Boston/Downtown', "Boston's Historic North End",
#        'Financial District', 'Downtown/Financial District', 'ALLSTON',
#        'Fenway/', 'Boston/Beacon Hill', 'BOSTON/CHINATOWN',
#        'Boston/Chinatown', 'Chinatown', 'Hyde Park/', 'BRIGHTON/',
#        'BOSTON/Waterfront', 'HYDE PARK', nan, 'MATTAPAN', 'West End/',
#        'Theater District', 'Mattapan/', 'Brighton/', '/',
#        'Allston/Boston', 'ROSLINDALE', 'Boston/Back Bay', 'Back Bay/',
#        'FENWAY', 'Brighton/Allston', 'BOSTON/Boston', 'Hyde PArk',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(["Mission Hill'",'Mission Hill//'], 'Mission Hill')
df_permits['city'] = df_permits['city'].replace(['ROSLINDALE','Roslindale/', 'Boston/Roslindale'], 'Roslindale')
df_permits['city'] = df_permits['city'].replace(['Mission Hill/', "Mission Hill'",'Mission Hill//'], 'Mission Hill')
df_permits['city'] = df_permits['city'].replace([ 'MATTAPAN ','MATTAPAN','Mattapan/','MATTAPAN'], 'Mattapan')
df_permits['city'] = df_permits['city'].replace(['NorthEnd/','NorthEnd','North End','Boston/North End','North end',"Boston's Historic North End",'NORTH END/WATERFRONT','BOSTON/Waterfront'], 'North End')
df_permits
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\992780778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(["Mission Hill'",'Mission Hill//'], 'Mission Hill')
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\992780778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['ROSLINDALE','Roslindale/', 'Boston/Roslindale'], 'Roslindale')
# ...

# %%
df_permits.city.unique()
# Out:
# array(['Boston', 'West Roxbury', 'Charlestown', 'Roxbury', 'Brighton',
#        'Allston', 'Jamaica Plain', 'East Boston', 'Dorchester',
#        'Hyde Park', 'South Boston', 'Roslindale', 'BOSTON',
#        'Mission Hill', 'Mattapan', 'Chestnut Hill', 'North End',
#        'Boston/West End', 'West End', 'Dorchester/', 'Fenway',
#        'South End', 'BOSTON/', 'Back Bay/Boston', ' ', 'Boston/',
#        'Boston/Downtown', "Boston's Historic North End",
#        'Financial District', 'Downtown/Financial District', 'ALLSTON',
#        'Fenway/', 'Boston/Beacon Hill', 'BOSTON/CHINATOWN',
#        'Boston/Chinatown', 'Chinatown', 'Hyde Park/', 'BRIGHTON/',
#        'BOSTON/Waterfront', 'HYDE PARK', nan, 'West End/',
#        'Theater District', 'Brighton/', '/', 'Allston/Boston',
#        'Boston/Back Bay', 'Back Bay/', 'FENWAY', 'Brighton/Allston',
#        'BOSTON/Boston', 'Hyde PArk', 'Financial District/',
#        'Boston/Fenway/Kenmore/Audubo', 'Allston/', 'roxbury', 'boston',
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['BOSTON/CHINATOWN','Boston/Chinatown','Boston/Chinatown','Chinatown/'], 'Chinatown')
df_permits['city'] = df_permits['city'].replace(['CHESTNUT HILL'],'Chestnut Hill' )
df_permits['city'] = df_permits['city'].replace(['ALLSTON','Allston/Boston','Allston/','Allston/Brighton'], 'Allston')
df_permits['city'] = df_permits['city'].replace(['Hyde Park/','HYDE PARK', 'Hyde PArk','Hyde Park//'], 'Hyde Park')
df_permits['city'] = df_permits['city'].replace(['West End','West End/','Boston/West End',], 'West End')
df_permits['city'] = df_permits['city'].replace(['Back Bay/Boston','Boston/Back Bay', 'Back Bay/','Back /'], 'Back Bay')
df_permits.city.unique()
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\1622714303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['BOSTON/CHINATOWN','Boston/Chinatown','Boston/Chinatown','Chinatown/'], 'Chinatown')
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\1622714303.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['CHESTNUT HILL'],'Chestnut Hill' )
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['BOSTON','BOSTON/Boston','BOSTON/','Boston/','boston','Boston/Downtown','Financial District', 'Theater District',
        'Boston/Downtown','Downtown/Financial','Downtown/Financial District','Financial District/',], 'Downtown/Financial District')
df_permits['city'] = df_permits['city'].replace(['Boston/Fenway','FENWAY','Boston/Fenway/Kenmore/Audubo'], 'Fenway')
df_permits['city'] = df_permits['city'].replace(['Beacon Hill/','Beacon Hill//','Boston/Beacon Hill',], 'Beacon Hill')
df_permits.city.unique()
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\3097639003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['BOSTON','BOSTON/Boston','BOSTON/','Boston/','boston','Boston/Downtown','Financial District', 'Theater District',
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\3097639003.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_permits['city'] = df_permits['city'].replace(['Dorchester/'], 'Dorchester')
df_permits['city'] = df_permits['city'].replace(['BRIGHTON/','Brighton/','Brighton/Allston'], 'Brighton')
df_permits['city'] = df_permits['city'].replace(['Fenway','Fenway/',], 'Kenmore/fenway')
df_permits['city'] = df_permits['city'].replace(['roxbury', 'Ropxbury',], 'Roxbury')
df_permits['city'] = df_permits['city'].replace(['Charlestown//'], 'Charlestown')
df_permits['city'] = df_permits['city'].replace([' ','nan','/'], 'Unknown')
df_permits.city.unique()
# Out:
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\2086832121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['Dorchester/'], 'Dorchester')
# C:\Users\shing\AppData\Local\Temp\ipykernel_6880\2086832121.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_permits['city'] = df_permits['city'].replace(['BRIGHTON/','Brighton/','Brighton/Allston'], 'Brighton')
# ...

# %%
df_permits
# Out:
#           zip                    address           city occupancytype  \
# 0       02109         181-183   State ST         Boston         Mixed
# 1       02132         175  W Boundary RD   West Roxbury          Comm
# 2       02129          15    Prospect ST    Charlestown        1-3FAM
# 3       02118      211  W Springfield ST        Roxbury         Multi
# 4       02135  14    William Jackson AVE       Brighton        1-2FAM
# ...       ...                        ...            ...           ...
# 566410  02108              3   Center PZ         Boston         Mixed
# 566411  02108              3   Center PZ         Boston         Mixed
# 566412  02134     1188   Commonwealth Av        Allston          Comm
# 566413  02130         46    Burroughs ST  Jamaica Plain        1-2FAM
# 566414  02124             17    Alpha RD     Dorchester        1-2FAM
#
#                    description worktype          issued_date  \
# 0       Interior/Exterior Work   INTEXT  2021-01-28 11:29:26
# ...

# %%
#Export_Hotels to csv for further processing on excel
df_permits.to_csv('df_permits.csv',encoding='utf-8')
