# %%
#Import the relevant Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#load neccessary data
crime_2022 = pd.read_csv('tmpattplu_0.csv',low_memory=False)
crime_2021 =pd.read_csv('tmp7_f32p54 (4).csv',low_memory=False)
crime_2020 = pd.read_csv('script_113631134_20210423193017_combine (3).csv',low_memory=False)
crime_2019 = pd.read_csv('tmp9mkqyv6b (3).csv',low_memory=False)
crime_2018 = pd.read_csv('crime-incident-reports-2018 (3).csv',low_memory=False)
crime_2017 = pd.read_csv('crime-incident-reports-2017 (3).csv',low_memory=False)
crime_2016 = pd.read_csv('crime-incident-reports-2016 (2).csv',low_memory=False)
crime_2015 = pd.read_csv('crime-incident-reports-2015 (3).csv',low_memory=False)

# %%
crime_2022
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           S87066666          3301                 NaN
# 1           225520077          3115                 NaN
# 2           223260108          3115                 NaN
# 3           222934485          3831                 NaN
# 4           222924960          3301                 NaN
# ...               ...           ...                 ...
# 66899       122004001          3115                 NaN
# 66900       111077848          3115                 NaN
# 66901       168393102          1402                 NaN
# 66902       149210376          3110                 NaN
# 66903       022031068          3114                 NaN
#
#                          OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                             VERBAL DISPUTE       B2            300
# 1                         INVESTIGATE PERSON      D14            786
# 2                         INVESTIGATE PERSON       D4            154
# ...

# %%
crime_2022.OFFENSE_DESCRIPTION.unique()
# Out:
# array(['VERBAL DISPUTE', 'INVESTIGATE PERSON',
#        'M/V - LEAVING SCENE - PROPERTY DAMAGE', 'PROPERTY - FOUND',
#        'MISSING PERSON - NOT REPORTED - LOCATED', 'FUGITIVE FROM JUSTICE',
#        'HARASSMENT/ CRIMINAL HARASSMENT', 'PROPERTY - LOST/ MISSING',
#        'FRAUD - CREDIT CARD / ATM FRAUD', 'LARCENY ALL OTHERS',
#        'AUTO THEFT', 'ROBBERY', 'LANDLORD - TENANT',
#        'WARRANT ARREST - BOSTON WARRANT (MUST BE SUPPLEMENTAL)',
#        'DRUGS - POSSESSION/ SALE/ MANUFACTURING/ USE', 'ASSAULT - SIMPLE',
#        'LARCENY THEFT FROM MV - NON-ACCESSORY', 'SICK ASSIST',
#        'BURGLARY - RESIDENTIAL', 'SERVICE TO OTHER AGENCY',
#        'ASSAULT - AGGRAVATED',
#        'M/V ACCIDENT - INVOLVING PEDESTRIAN - NO INJURY',
#        'M/V ACCIDENT - OTHER', 'LICENSE PREMISE VIOLATION',
#        'VAL - OPERATING AFTER REV/SUSP.', 'VANDALISM',
#        'FIREARM/WEAPON - FOUND OR CONFISCATED', 'INVESTIGATE PROPERTY',
# ...

# %%
import fuzzywuzzy as fuzzywuzzy
from fuzzywuzzy import process, fuzz

# %%
#Look at Violent crimes, Violent Crime
#In the FBI’s Uniform Crime Reporting (UCR) Program, violent crime is composed of four offenses: murder and nonnegligent manslaughter, forcible rape, robbery, and aggravated assault. Violent crimes are defined in the UCR Program as those offenses which involve force or threat of force.


string_to_match = 'murder'
min_ratio = 90
    # get a list of unique strings
strings = crime_2022.OFFENSE_DESCRIPTION.unique()

    # get the top 5 closest matches to our input string
matches = fuzzywuzzy.process.extract(string_to_match, strings, limit=5, scorer=fuzzywuzzy.fuzz.token_set_ratio)
# only get matches with a ratio >   
print(matches)
# Out:
# [('MURDER, NON-NEGLIGENT MANSLAUGHTER', 100), ('MURDER, NON-NEGLIGIENT MANSLAUGHTER', 100), ('ROBBERY', 46), ('FRAUD - WELFARE', 42), ('PROPERTY - FOUND', 40)]

# %%
string_to_match = 'robbery'
min_ratio = 90
    # get a list of unique strings
strings = crime_2022.OFFENSE_DESCRIPTION.unique()

    # get the top 5 closest matches to our input string
matches = fuzzywuzzy.process.extract(string_to_match, strings, limit=5, scorer=fuzzywuzzy.fuzz.token_set_ratio)
# only get matches with a ratio >   
print(matches)
# Out:
# [('ROBBERY', 100), ('PROPERTY - FOUND', 48), ('INVESTIGATE PROPERTY', 37), ('PROPERTY - LOST/ MISSING', 36), ('FORGERY / COUNTERFEITING', 34)]

# %%
string_to_match = 'assault'
min_ratio = 90
    # get a list of unique strings
strings = crime_2022.OFFENSE_DESCRIPTION.unique()

    # get the top 5 closest matches to our input string
matches = fuzzywuzzy.process.extract(string_to_match, strings, limit=5, scorer=fuzzywuzzy.fuzz.token_set_ratio)
# only get matches with a ratio >   
print(matches)
# Out:
# [('ASSAULT - SIMPLE', 100), ('ASSAULT - AGGRAVATED', 100), ('SICK ASSIST', 44), ('ANIMAL ABUSE', 42), ('VANDALISM', 38)]

# %%
string_to_match = 'drugs'
min_ratio = 90
    # get a list of unique strings
strings = crime_2022.OFFENSE_DESCRIPTION.unique()

    # get the top 5 closest matches to our input string
matches = fuzzywuzzy.process.extract(string_to_match, strings, limit=5, scorer=fuzzywuzzy.fuzz.token_set_ratio)
# only get matches with a ratio >   
print(matches)
# Out:
# [('DRUGS - POSSESSION/ SALE/ MANUFACTURING/ USE', 100), ('DRUGS - POSSESSION OF DRUG PARAPHANALIA', 100), ('OPERATING UNDER THE INFLUENCE (OUI) DRUGS', 100), ('DRUNKENNESS', 50), ('ARSON', 40)]

# %%
violent_crime_2022 = crime_2022.loc[(crime_2022['OFFENSE_DESCRIPTION'] == 'MURDER, NON-NEGLIGENT MANSLAUGHTER') |
                                (crime_2022['OFFENSE_DESCRIPTION'] ==     'MURDER, NON-NEGLIGIENT MANSLAUGHTER') |
                                (crime_2022['OFFENSE_DESCRIPTION'] == 'ROBBERY')|
                                (crime_2022['OFFENSE_DESCRIPTION'] ==  'ASSAULT - AGGRAVATED')]
                             
                                                  
violent_crime_2022
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 17          222201559           301                 NaN               ROBBERY
# 31          222091588           423                 NaN  ASSAULT - AGGRAVATED
# 83          222091500           423                 NaN  ASSAULT - AGGRAVATED
# 114         222091451           301                 NaN               ROBBERY
# 139         222091415           423                 NaN  ASSAULT - AGGRAVATED
# ...               ...           ...                 ...                   ...
# 66720       222034143           423                 NaN  ASSAULT - AGGRAVATED
# 66797       222034042           423                 NaN  ASSAULT - AGGRAVATED
# 66843       222033981           423                 NaN  ASSAULT - AGGRAVATED
# 66862       222033953           301                 NaN               ROBBERY
# 66891       222088987           423                 NaN  ASSAULT - AGGRAVATED
#
# ...

# %%
string_to_match1 = 'robbery'
string_to_match2 = 'murder'
string_to_match3 = 'assault'
min_ratio = 90
    # get a list of unique strings
strings = crime_2021.OFFENSE_DESCRIPTION.unique()

    # get the top 5 closest matches to our input string
matches1 = fuzzywuzzy.process.extract(string_to_match1, strings, limit=5, scorer=fuzzywuzzy.fuzz.token_set_ratio)
matches2 = fuzzywuzzy.process.extract(string_to_match2, strings, limit=5, scorer=fuzzywuzzy.fuzz.token_set_ratio)
matches3 = fuzzywuzzy.process.extract(string_to_match, strings, limit=5, scorer=fuzzywuzzy.fuzz.token_set_ratio)
# only get matches with a ratio >   
dfmatches1, matches2, matches3)
# Out:
# [('ROBBERY', 100), ('PROPERTY - FOUND', 48), ('INVESTIGATE PROPERTY', 37), ('PROPERTY - LOST/ MISSING', 36), ('FORGERY / COUNTERFEITING', 34)] [('MURDER, NON-NEGLIGIENT MANSLAUGHTER', 100), ('ROBBERY', 46), ('FRAUD - WELFARE', 42), ('PROPERTY - FOUND', 40), ('FRAUD - WIRE', 38)] [('ROBBERY', 100), ('PROPERTY - FOUND', 48), ('INVESTIGATE PROPERTY', 37), ('PROPERTY - LOST/ MISSING', 36), ('FORGERY / COUNTERFEITING', 34)]

# %%
violent_crime_2021= crime_2021.loc[(crime_2021['OFFENSE_DESCRIPTION'] == 'MURDER, NON-NEGLIGENT MANSLAUGHTER') |
                             (crime_2021['OFFENSE_DESCRIPTION'] == 'ROBBERY')|
                             (crime_2021['OFFENSE_DESCRIPTION'] ==  'ASSAULT - AGGRAVATED')]
                             
                                                  
violent_crime_2021
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 95          212095529           423                 NaN  ASSAULT - AGGRAVATED
# 136         212095467           301                 NaN               ROBBERY
# 152         212095448           301                 NaN               ROBBERY
# 158         212095441           423                 NaN  ASSAULT - AGGRAVATED
# 209         212095368           301                 NaN               ROBBERY
# ...               ...           ...                 ...                   ...
# 71324       210046064           423                 NaN  ASSAULT - AGGRAVATED
# 71370       212090399           423                 NaN  ASSAULT - AGGRAVATED
# 71657       212089785           423                 NaN  ASSAULT - AGGRAVATED
# 71659       212089783           423                 NaN  ASSAULT - AGGRAVATED
# 71681       212092237           301                 NaN               ROBBERY
#
# ...

# %%
violent_crime_2020= crime_2020.loc[(crime_2020['OFFENSE_DESCRIPTION'] == 'MURDER, NON-NEGLIGENT MANSLAUGHTER') |
                             (crime_2020['OFFENSE_DESCRIPTION'] == 'ROBBERY')|
                             (crime_2020['OFFENSE_DESCRIPTION'] ==  'ASSAULT - AGGRAVATED')]
                             
                                                  
violent_crime_2020
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 122         202074423           423                 NaN  ASSAULT - AGGRAVATED
# 178         202069145           301                 NaN               ROBBERY
# 322         212001699           423                 NaN  ASSAULT - AGGRAVATED
# 374         212000805           301                 NaN               ROBBERY
# 383         212000722           423                 NaN  ASSAULT - AGGRAVATED
# ...               ...           ...                 ...                   ...
# 70769       202000022           301                 NaN               ROBBERY
# 70815       200293622           423                 NaN  ASSAULT - AGGRAVATED
# 70820       200284533           301                 NaN               ROBBERY
# 70838       200204397           301                 NaN               ROBBERY
# 70860       200063547           423                 NaN  ASSAULT - AGGRAVATED
#
# ...

# %%
violent_crime_2019 = crime_2019.loc[(crime_2019['OFFENSE_DESCRIPTION'] == 'MURDER, NON-NEGLIGENT MANSLAUGHTER') |
                             (crime_2019['OFFENSE_DESCRIPTION'] == 'ROBBERY')|
                             (crime_2019['OFFENSE_DESCRIPTION'] ==  'ASSAULT - AGGRAVATED')]
                             
                                                  
violent_crime_2019
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 43          191101616           301                 NaN               ROBBERY
# 219         192078655           301                 NaN               ROBBERY
# 299         192078763           301                 NaN               ROBBERY
# 353         192078824           423                 NaN  ASSAULT - AGGRAVATED
# 366         192078845           423                 NaN  ASSAULT - AGGRAVATED
# ...               ...           ...                 ...                   ...
# 86537       192075085           423                 NaN  ASSAULT - AGGRAVATED
# 86660       192077010           423                 NaN  ASSAULT - AGGRAVATED
# 86749       192076281           423                 NaN  ASSAULT - AGGRAVATED
# 86761       192076324           423                 NaN  ASSAULT - AGGRAVATED
# 87005       192077602           423                 NaN  ASSAULT - AGGRAVATED
#
# ...

# %%
violent_crime_2018= crime_2018.loc[(crime_2018['OFFENSE_DESCRIPTION'] == 'MURDER, NON-NEGLIGENT MANSLAUGHTER') |
                             (crime_2018['OFFENSE_DESCRIPTION'] == 'ROBBERY')|
                             (crime_2018['OFFENSE_DESCRIPTION'] ==  'ASSAULT - AGGRAVATED')]
                             
                                                  
violent_crime_2018
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 502        I192003189           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 563        I192002037           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 757        I182105265           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 798        I182105210           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 955        I182105034           423  Aggravated Assault  ASSAULT - AGGRAVATED
# ...               ...           ...                 ...                   ...
# 98174      I182000616           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 98378      I182000354           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 98489      I182000217           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 98701      I172075311           423  Aggravated Assault  ASSAULT - AGGRAVATED
# 98764      I172034897           423  Aggravated Assault  ASSAULT - AGGRAVATED
#
# ...

# %%
violent_crime_2017= crime_2017.loc[(crime_2017['OFFENSE_DESCRIPTION'] == 'MURDER, NON-NEGLIGENT MANSLAUGHTER') |
                             (crime_2017['OFFENSE_DESCRIPTION'] == 'ROBBERY')|
                             (crime_2017['OFFENSE_DESCRIPTION'] ==  'ASSAULT - AGGRAVATED')]
                             
                                                  
violent_crime_2017
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 276         I182027604           423  Aggravated Assault
# 330         I182021436           423  Aggravated Assault
# 597         I182003042           423  Aggravated Assault
# 805         I182000008           423  Aggravated Assault
# 864         I172107648           423  Aggravated Assault
# ...                ...           ...                 ...
# 101067      I172000103           423  Aggravated Assault
# 101176      I162089079           423  Aggravated Assault
# 101182      I162088861           423  Aggravated Assault
# 101187      I162087964           423  Aggravated Assault
# 101211      I162073342           423  Aggravated Assault
#
#          OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 276     ASSAULT - AGGRAVATED      E18            534      NaN
# 330     ASSAULT - AGGRAVATED       E5            685      NaN
# 597     ASSAULT - AGGRAVATED      E13            635      NaN
# ...
